# %%
import pandas as pd

df = pd.read_csv("voca.csv")
df
# Out:
#             영어  Day       형용사                                 동사  \
# 0       annual    1  연례의, 매년의                                NaN
# 1       rental    1       NaN                                NaN
# 2     proceeds    1       NaN                                NaN
# 3      deliver    1       NaN  배송하다, 배달하다, 전달하다, (연설이나 강연 등을) 하다
# 4       refund    1       NaN                              환불하다
# ...        ...  ...       ...                                ...
# 1795  reminder   60       NaN                                NaN
# 1796  purifier   60       NaN                                NaN
# 1797  dispense   60       NaN         내주다, (약사가 약을) 조제하다, 나누어 주다
# 1798    outlet   60       NaN                                NaN
# 1799  subtitle   60       NaN                                NaN
#
#                  명사  전치사   부사  대명사  접속사  감탄사
# 0               NaN  NaN  NaN  NaN  NaN  NaN
# 1            대여, 임대  NaN  NaN  NaN  NaN  NaN
# 2             수익(금)  NaN  NaN  NaN  NaN  NaN
# 3               NaN  NaN  NaN  NaN  NaN  NaN
# 4                환불  NaN  NaN  NaN  NaN  NaN
# ...             ...  ...  ...  ...  ...  ...
# 1795  상기시켜 주는 메모[것]  NaN  NaN  NaN  NaN  NaN
# 1796          정화 장치  NaN  NaN  NaN  NaN  NaN
# 1797            NaN  NaN  NaN  NaN  NaN  NaN
# 1798  배출구, 콘센트, 할인점  NaN  NaN  NaN  NaN  NaN
# 1799             자막  NaN  NaN  NaN  NaN  NaN
#
# [1800 rows x 10 columns]

# %%
# Count non-null values in each column
non_null_counts = df.count()
print("Number of non-null values in each column:")
print(non_null_counts)
# Out:
# Number of non-null values in each column:
# 영어     1800
# Day    1800
# 형용사     466
# 동사      637
# 명사      941
# 전치사       1
# 부사       28
# 대명사       0
# 접속사       0
# 감탄사       0
# dtype: int64

# %%
# Remove unnecessary columns
df = df.drop(['대명사', '접속사', '감탄사'], axis=1)

# %%
df.count()
# Out:
# 영어     1800
# Day    1800
# 형용사     466
# 동사      637
# 명사      941
# 전치사       1
# 부사       28
# dtype: int64

# %%
# Export to new CSV file without removed columns
df.to_csv('voca_cleaned.csv', index=False)
